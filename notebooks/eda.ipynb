# %% [markdown]
# # Machine Learning in Computational biology #
# ## Assignment 2 ##

# %% [markdown]
# Import required libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../src')


from IPython.display import display
import pandas as pd
import numpy as np
import matplotlib as mpl
import numpy as np

from functions_eda import overview
from functions_eda import find_outliers
from functions_eda import class_imbalance_binary
from functions_eda import plot_continuous_features
from functions_eda import plot_categorical_features
from functions_eda import plot_correlation_heatmap
from functions_eda import plot_pca

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# 1. Load the clinical data CSV File

# %%
df = pd.read_csv("../data/heart.csv")
overview(df)
# Out:
# Peek into the dataset
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  48.0  1.0  4.0     124.0  274.0  0.0      2.0    166.0    0.0      0.5
# 1  55.0  1.0  2.0     130.0  262.0  0.0      0.0    155.0    0.0      0.0
# 2  54.0  0.0  2.0     132.0  288.0  1.0      2.0    159.0    1.0      0.0
# 3  54.0  1.0  2.0     108.0  309.0  0.0      0.0    156.0    0.0      0.0
# 4  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
#
#    slope   ca  thal  num
# 0    2.0  0.0   7.0    1
# 1    1.0  0.0   3.0    0
# 2    1.0  1.0   3.0    0
# 3    1.0  0.0   7.0    0
# 4    2.0  0.0   7.0    1
# 1. General Summary:
#                  Metric  Value
# 0                  Rows    242
# 1               Columns     14
# 2        Duplicate Rows      0
# 3  Total Missing Values      2
# 2. Data Types:
# Numerical features: 14
# Categorical features: 0
#             dtype
# age       float64
# sex       float64
# cp        float64
# ...

# %% [markdown]
# ### Outlier Detection ##

# %%
find_outliers(df)
# Out:
# Continuous columns detected: ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
#              Q1      Q3    IQR  lower_bound  upper_bound  n_outliers  \
# feature
# age        48.0   61.00  13.00        28.50        80.50           0
# trestbps  120.0  140.00  20.00        90.00       170.00           6
# chol      212.0  277.75  65.75       113.38       376.38           5
# thalach   134.5  166.00  31.50        87.25       213.25           1
# oldpeak     0.0    1.60   1.60        -2.40         4.00           4
#
#           outlier_%                              outlier_values
# feature
# age            0.00                                          []
# trestbps       2.48  [172.0, 180.0, 178.0, 200.0, 192.0, 180.0]
# chol           2.07         [407.0, 417.0, 409.0, 564.0, 394.0]
# thalach        0.41                                      [71.0]
# oldpeak        1.65                        [5.6, 6.2, 4.2, 4.2]

# %% [markdown]
# ### Class imbalance ###

# %%
class_imbalance_binary(df)
# Out:
#    Class  Count  Percentage          Label
# 0      0    131       54.13     No Disease
# 1      1    111       45.87  Heart Disease

# %% [markdown]
# ### Distribution of features by Class label - continuous ###

# %%
plot_continuous_features(df)

# %% [markdown]
# ### Distribution of features by Class label - categorical and binary ###

# %%
plot_categorical_features(df)

# %% [markdown]
# ### Feature Correlation Heatmap ###

# %%
plot_correlation_heatmap(df)

# %%
plot_pca(df)
# Out:
# PC1 explains 27.0% of variance
# PC2 explains 14.0% of variance
# Total explained: 41.0%
